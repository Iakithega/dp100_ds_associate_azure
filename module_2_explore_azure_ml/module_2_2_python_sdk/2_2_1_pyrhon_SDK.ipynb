# %%
# from azure.ai.ml import MLClient
import azure.ai.ml
from azure.identity import DefaultAzureCredential
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # from azure.ai.ml import MLClient
# ----> 2 import azure.ai.ml
#       3 from azure.identity import DefaultAzureCredential
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\__init__.py:11
#       8 from typing import Any, Optional
#      10 # from .entities._builders.parallel_func import parallel
# ---> 11 from azure.ai.ml.entities._inputs_outputs import Input, Output
#      13 from ._ml_client import MLClient
#      14 from ._utils._logger_utils import initialize_logger_info
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\__init__.py:19
#      16 from azure.ai.ml._restclient.v2022_10_01_preview.models import UsageUnit
#      18 from ._assets._artifacts._package.base_environment_source import BaseEnvironment
# ---> 19 from ._assets._artifacts._package.inferencing_server import (
#      20     AzureMLBatchInferencingServer,
#      21     AzureMLOnlineInferencingServer,
#      22     CustomInferencingServer,
#      23     Route,
#      24     TritonInferencingServer,
#      25 )
#      26 from ._assets._artifacts._package.model_configuration import ModelConfiguration
#      27 from ._assets._artifacts._package.model_package import (
#      28     ModelPackage,
#      29     ModelPackageInput,
#    (...)
#      32     PackageInputPathVersion,
#      33 )
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_assets\_artifacts\_package\inferencing_server.py:26
#      21 from azure.ai.ml._restclient.v2023_08_01_preview.models import (
#      22     AzureMLOnlineInferencingServer as RestAzureMLOnlineInferencingServer,
#      23 )
#      24 from azure.ai.ml._utils._experimental import experimental
# ---> 26 from ...._deployment.code_configuration import CodeConfiguration
#      29 @experimental
#      30 class AzureMLOnlineInferencingServer:
#      31     """Azure ML online inferencing configurations.
#      32
#      33     :param code_configuration: The code configuration of the inferencing server.
#      34     :type code_configuration: str
#      35     :ivar type: The type of the inferencing server.
#      36     """
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_deployment\code_configuration.py:10
#       7 from typing import Optional, Union
#       9 from azure.ai.ml._restclient.v2022_05_01.models import CodeConfiguration as RestCodeConfiguration
# ---> 10 from azure.ai.ml.entities._assets import Code
#      11 from azure.ai.ml.entities._mixins import DictMixin
#      12 from azure.ai.ml.exceptions import ErrorCategory, ErrorTarget, ValidationErrorType, ValidationException
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_assets\__init__.py:9
#       5 __path__ = __import__("pkgutil").extend_path(__path__, __name__)
#       8 from ._artifacts.artifact import Artifact
# ----> 9 from ._artifacts.code import Code
#      10 from ._artifacts.data import Data
#      11 from ._artifacts.index import Index
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_assets\_artifacts\code.py:16
#      14 from azure.ai.ml.entities._assets import Artifact
#      15 from azure.ai.ml.entities._system_data import SystemData
# ---> 16 from azure.ai.ml.entities._util import load_from_dict
#      18 from .artifact import ArtifactStorageInfo
#      21 class Code(Artifact):
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_util.py:20
#      18 from .._restclient.v2023_04_01_preview.models import JobOutput as RestJobOutput
#      19 from .._schema._datastore import AzureBlobSchema, AzureDataLakeGen1Schema, AzureDataLakeGen2Schema, AzureFileSchema
# ---> 20 from .._schema._deployment.batch.batch_deployment import BatchDeploymentSchema
#      21 from .._schema._deployment.online.online_deployment import (
#      22     KubernetesOnlineDeploymentSchema,
#      23     ManagedOnlineDeploymentSchema,
#      24 )
#      25 from .._schema._endpoint.batch.batch_endpoint import BatchEndpointSchema
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\_schema\_deployment\batch\batch_deployment.py:21
#      19 from azure.ai.ml._schema.core.fields import ComputeField, NestedField, StringTransformedEnum
#      20 from azure.ai.ml._schema.job.creation_context import CreationContextSchema
# ---> 21 from azure.ai.ml._schema.pipeline.pipeline_component import PipelineComponentFileRefField
#      22 from azure.ai.ml.constants._common import AzureMLResourceType
#      23 from azure.ai.ml._schema.job_resource_configuration import JobResourceConfigurationSchema
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\_schema\pipeline\__init__.py:7
#       1 # ---------------------------------------------------------
#       2 # Copyright (c) Microsoft Corporation. All rights reserved.
#       3 # ---------------------------------------------------------
#       4 # pylint: disable=unused-import
#       5 __path__ = __import__("pkgutil").extend_path(__path__, __name__)
# ----> 7 from .component_job import (
#       8     CommandSchema,
#       9     ImportSchema,
#      10     ParallelSchema,
#      11     SparkSchema,
#      12     DataTransferCopySchema,
#      13     DataTransferImportSchema,
#      14     DataTransferExportSchema,
#      15 )
#      16 from .pipeline_job import PipelineJobSchema
#      17 from .settings import PipelineJobSettingsSchema
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\_schema\pipeline\component_job.py:27
#      25 from ...constants._common import AzureMLResourceType
#      26 from ...constants._component import DataTransferTaskType, NodeType
# ---> 27 from ...entities._inputs_outputs import Input
#      28 from ...entities._job.pipeline._attr_dict import _AttrDict
#      29 from ...exceptions import ValidationException
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_inputs_outputs\__init__.py:57
#       1 # ---------------------------------------------------------
#       2 # Copyright (c) Microsoft Corporation. All rights reserved.
#       3 # ---------------------------------------------------------
#       5 """This package includes the type classes which could be used in dsl.pipeline,
#       6 command function, or any other place that requires job inputs/outputs.
#       7
#    (...)
#      54         node = my_command()
#      55 """
# ---> 57 from .enum_input import EnumInput
#      58 from .external_data import Database, FileSystem
#      59 from .group_input import GroupInput
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_inputs_outputs\enum_input.py:10
#       6 from typing import Any, Iterable, List, Optional, Sequence, Tuple, Union
#       8 from azure.ai.ml.exceptions import ErrorCategory, ErrorTarget, ValidationErrorType, ValidationException
# ---> 10 from .input import Input
#      13 class EnumInput(Input):
#      14     """Enum parameter parse the value according to its enum values."""
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_inputs_outputs\input.py:25
#      16 from azure.ai.ml.exceptions import (
#      17     ErrorCategory,
#      18     ErrorTarget,
#    (...)
#      21     ValidationException,
#      22 )
#      24 from .base import _InputOutputBase
# ---> 25 from .utils import _get_param_with_standard_annotation, _remove_empty_values
#      28 class Input(_InputOutputBase):  # pylint: disable=too-many-instance-attributes
#      29     """Initialize an Input object.
#      30
#      31     :keyword type: The type of the data input. Accepted values are
#    (...)
#      71             :caption: Creating a CommandJob with two inputs.
#      72     """
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\site-packages\azure\ai\ml\entities\_inputs_outputs\utils.py:28
#      23     from .output import Output
#      25 SUPPORTED_RETURN_TYPES_PRIMITIVE = list(IOConstants.PRIMITIVE_TYPE_2_STR.keys())
# ---> 28 Annotation: TypeAlias = Union[str, Type, Annotated, None]  # type: ignore
#      31 def is_group(obj: object) -> bool:
#      32     """Return True if obj is a group or an instance of a parameter group class.
#      33
#      34     :param obj: The object to check.
#    (...)
#      37     :rtype: bool
#      38     """
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\typing.py:432, in _tp_cache.<locals>.decorator.<locals>.inner(*args, **kwds)
#     430 except TypeError:
#     431     pass  # All real errors (not unhashable args) are raised below.
# --> 432 return func(*args, **kwds)
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\typing.py:576, in _SpecialForm.__getitem__(self, parameters)
#     574 @_tp_cache
#     575 def __getitem__(self, parameters):
# --> 576     return self._getitem(self, parameters)
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\typing.py:789, in Union(self, parameters)
#     787     parameters = (parameters,)
#     788 msg = "Union[arg, ...]: each arg must be a type."
# --> 789 parameters = tuple(_type_check(p, msg) for p in parameters)
#     790 parameters = _remove_dups_flatten(parameters)
#     791 if len(parameters) == 1:
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\typing.py:789, in <genexpr>(.0)
#     787     parameters = (parameters,)
#     788 msg = "Union[arg, ...]: each arg must be a type."
# --> 789 parameters = tuple(_type_check(p, msg) for p in parameters)
#     790 parameters = _remove_dups_flatten(parameters)
#     791 if len(parameters) == 1:
#
# File c:\Users\dvolf\Anaconda3\envs\dp100\Lib\typing.py:200, in _type_check(arg, msg, is_argument, module, allow_special_forms)
#     198     return arg
#     199 if isinstance(arg, _SpecialForm) or arg in (Generic, Protocol):
# --> 200     raise TypeError(f"Plain {arg} is not valid as type argument")
#     201 if type(arg) is tuple:
#     202     raise TypeError(f"{msg} Got {arg!r:.100}.")
#
# TypeError: Plain typing.Annotated is not valid as type argument

# %% [markdown]
# ## Connect to the workspace
# After the Python SDK is installed, you'll need to connect to the workspace. By connecting, you're authenticating your environment to interact with the workspace to create and manage assets and resources.
#
# To authenticate, you need the values to three necessary parameters:
#
# #### subscription_id: Your subscription ID.
# #### resource_group: The name of your resource group.
# #### workspace_name: The name of your workspace.

# %%
print(azure.ai.ml.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(azure.ai.ml.__version__)
#
# NameError: name 'azure' is not defined

# %%
try:
    import azure.ai.ml
    print("Azure ML SDK version:", azure.ai.ml.__version__)
except ImportError as e:
    print("Import Error:", e)
except Exception as e:
    print("Other Error:", e)
# Out:
# Other Error: Plain typing.Annotated is not valid as type argument

# %%
import sys
print(sys.version)
# Out:
# 3.13.1 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 17:02:46) [MSC v.1929 64 bit (AMD64)]
